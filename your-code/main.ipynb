# %% [markdown]
# # LAB: Practice with Tavily + LangChain Agents
#
# ### Objective
# Reinforce your understanding of LangChain agents integrated with Tavily for real-time web search by solving two open-ended tasks. You'll:
# - Load and configure a LangChain agent with Tavily
# - Build effective prompts
# - Generate structured, useful outputs from real-time data

# %% [markdown]
# ### Setup

# %%
import os
from langchain.agents import initialize_agent, AgentType, Tool
from langchain.chat_models import ChatOpenAI
from langchain.tools.tavily_search import TavilySearchResults
import tiktoken
from IPython.display import Markdown, display
from  dotenv import load_dotenv
import warnings
warnings.filterwarnings('ignore')
from langchain.tools.tavily_search import TavilySearchResults

load_dotenv()
tavily_search = TavilySearchResults()

# LLM + Encoding
llm = ChatOpenAI(model="gpt-4", temperature=0)
encoding = tiktoken.encoding_for_model("gpt-4")

# Safe Tavily wrapper
def safe_search(query: str) -> str:
    result = tavily_search.run(query)

    # Ensure result is a string — Tavily returns dict with 'snippets' sometimes
    if isinstance(result, dict):
        result_text = result.get("content", "") or str(result)
    else:
        result_text = str(result)

    tokens = encoding.encode(result_text)
    trimmed = encoding.decode(tokens[:3500])  # leave room for GPT-4 response
    return trimmed


# LangChain tool
tools = [Tool(name="TavilySafeSearch", func=safe_search, description="Web search tool")]
agent = initialize_agent(tools=tools, llm=llm, agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION, verbose=True)

# %% [markdown]
# ### Exercise 1: AI in Healthcare
#
# Goal: Investigate and summarize the latest advancements in generative AI applied to healthcare in 2025.
#
# - Design a prompt that asks the agent to retrieve the most recent updates.
# - Ensure the agent outputs a structured response in Markdown.

# %%
# Your prompt here
prompt_1 = """
Investigate and summarize the latest developments in generative AI models published in 2026. Retrieve the most recent updates.

Output must be in Markdown format with:
- Main heading: Latest Generative AI (2025)
- Subheadings per key model or development
- Bullet points for features
- Source links if any
Keep it concise.


"""

# Run it
response_1 = agent.run(prompt_1)
# Out:
# > Entering new AgentExecutor chain...
# I need to search for the latest developments in generative AI models published in 2026. I will use TavilySafeSearch to find this information.
# Action: TavilySafeSearch
# Action Input: Latest developments in generative AI models 2026
# Observation: [{'url': 'https://tblocks.com/articles/generative-ai-trends/', 'content': 'Most organizations are aware of the limitations of ungrounded AI models. In 2026, retrieval-augmented generation (RAG) is evolving from a bolt-on capability into a governed knowledge fabric. This includes curated sources, permissioning, freshness rules, and evaluation metrics directly tied to business outcomes. In 2025, RAG was already a common enterprise technique, while advanced methods like fine-tuning were largely restricted to frontier teams.\n\nThis is where AI governance becomes real engineering. The target is repeatable correctness under business constraints, with provenance and logs that stand up to audit. This is also where responsible AI moves from policy to product requirements, because your knowledge layer defines what the model is allowed to say. [...] This growth is transforming GenAI from an experimental technology into a repeatable system that is reliable, auditable, and financially defensible. Leading organizations embed AI agents into real workflows, build AI-native delivery systems that operate like production lines, and maintain governed knowledge to ensure models remain grounded in verifiable, defensible business information. Treating generative AI as a core operating capability allows enterprises to drive consistent business value while maintaining control, accountability, and compliance.\n\n## Why 2026 Feels Like a Pivot Year for Generative AI [...] ## The Top 10 Generative AI Trends for 2026\n\nA useful 2026 trend list clarifies what becomes standard. In 2026, generative AI stops being a layer of productivity tools and becomes a layer of enterprise execution:\n\n### 1. Agentic Workflows Become a Standard Operating Layer\n\nThe practical rise of agentic AI is redefining how work gets done. Instead of serving purely as advisors in chat windows, AI agents now plan tasks, call tools, route decisions, and escalate exceptions, shifting from assistance to agency.'}, {'url': 'https://www.ibm.com/think/news/ai-tech-trends-predictions-2026', 'content': 'Generative models need to be multisensory so they can interpret the world like humans and even detect signals we might miss, said Aaron Baughman, IBM Fellow and Master Inventor, in a recent episode of Mixture of Experts.\n\nBaughman has worked with multimodal AI in sports and leads some of IBM’s work with the US Open, ESPN Fantasy Football and the Masters, notably. For him, multimodal AI is a trend he expects to see more of in 2026.\n\n“These models will be able to perceive and act in a world much more like a human. They’ll be able to bridge language, vision and action, all together,” he said. “In the near future, we’re to start seeing these multimodal digital workers that can autonomously complete these different tasks to interpret things, maybe even like complex healthcare cases.” [...] “We’ll begin to see decentralized networks of agents that can learn from each other, share information and retain important knowledge over long horizons—weeks, months, even years,” he said. “These systems will improve dynamism and continuous improvement while allowing agents and models to specialize into efficient, focused capabilities.”\n\n### Collaborative defenses will fight weaponized AI | Ben Colman, CEO & Cofounder, Reality Defender\n\nNo single entity can solve the deepfake and weaponized AI crisis, especially as new threat vectors—like weaponized AI agents—emerged at the tail end of this year, said Ben Colman, CEO & Cofounder of Reality Defender, a cybersecurity company offering deepfake detection tools. The rapid evolution of generative AI demands a collaborative ecosystem. [...] Purchase an individual or multi-user subscription today to access our full catalog of over 100 online courses. Expand your skills across a wide range of our products at a low price.\n\nLearn how organizations are shifting from launching AI in disparate pilots to using it to drive transformation at the core.\ ...
# Thought:I have found several key developments in generative AI models in 2026. I will now organize this information into the required Markdown format.
# Final Answer:
# # Latest Generative AI (2026)
#
# ## Retrieval-Augmented Generation (RAG)
# - Evolved from a bolt-on capability into a governed knowledge fabric
# - Includes curated sources, permissioning, freshness rules, and evaluation metrics tied to business outcomes
# - Transformed GenAI from an experimental technology into a repeatable system that is reliable, auditable, and financially defensible
# - [Source](https://tblocks.com/articles/generative-ai-trends/)
#
# ## Multisensory Generative Models
# - Models interpret the world like humans and can detect signals we might miss
# - Bridge language, vision, and action together
# - Expected to see more multimodal digital workers that can autonomously complete different tasks
# - [Source](https://www.ibm.com/think/news/ai-tech-trends-predictions-2026)
#
# ## Top Generative AI Models
# - Gemini 3 Pro, GPT 5.2, and Clause Opus 4.5 were the best at the beginning of 2026 for both general-purpose and specific tasks related scenarios
# - Open source alternatives are getting into the top-10 models
# - [Source](https://virtuslab.com/blog/ai/best-gen-ai-beginning-2026/)
#
# ## Generative AI as an Organizational Resource
# - Greater focus on generative AI as an organizational resource rather than an individual one
# - Shift from implementing GenAI as a primarily individual-based approach to an enterprise-level one
# - [Source](https://sloanreview.mit.edu/article/five-trends-in-ai-and-data-science-for-2026/)
#
# ## Generative AI in Healthcare
# - AI moving beyond expertise in diagnostics and extending into areas like symptom triage and treatment planning
# - New generative AI products and services available to millions of consumers and patients
# - [Source](https://news.microsoft.com/source/features/ai/whats-next-in-ai-7-trends-to-watch-in-2026/)
#
# > Finished chain.

# %%
display(Markdown(response_1))
# Out:
# # Latest Generative AI (2026)
#
# ## Retrieval-Augmented Generation (RAG)
# - Evolved from a bolt-on capability into a governed knowledge fabric
# - Includes curated sources, permissioning, freshness rules, and evaluation metrics tied to business outcomes
# - Transformed GenAI from an experimental technology into a repeatable system that is reliable, auditable, and financially defensible
# - [Source](https://tblocks.com/articles/generative-ai-trends/)
#
# ## Multisensory Generative Models
# - Models interpret the world like humans and can detect signals we might miss
# - Bridge language, vision, and action together
# - Expected to see more multimodal digital workers that can autonomously complete different tasks
# - [Source](https://www.ibm.com/think/news/ai-tech-trends-predictions-2026)
#
# ## Top Generative AI Models
# - Gemini 3 Pro, GPT 5.2, and Clause Opus 4.5 were the best at the beginning of 2026 for both general-purpose and specific tasks related scenarios
# - Open source alternatives are getting into the top-10 models
# - [Source](https://virtuslab.com/blog/ai/best-gen-ai-beginning-2026/)
#
# ## Generative AI as an Organizational Resource
# - Greater focus on generative AI as an organizational resource rather than an individual one
# - Shift from implementing GenAI as a primarily individual-based approach to an enterprise-level one
# - [Source](https://sloanreview.mit.edu/article/five-trends-in-ai-and-data-science-for-2026/)
#
# ## Generative AI in Healthcare
# - AI moving beyond expertise in diagnostics and extending into areas like symptom triage and treatment planning
# - New generative AI products and services available to millions of consumers and patients
# - [Source](https://news.microsoft.com/source/features/ai/whats-next-in-ai-7-trends-to-watch-in-2026/)

# %% [markdown]
# ### Exercise 2: AI Startups Landscape
#
# Goal: Track 2025’s top emerging AI startups and their innovations.
#
# - Create a prompt that instructs the agent to deliver a clean Markdown summary.
# - Tip: Ask for company names, product highlights, and sources.

# %%
# Your prompt here
prompt_2 = """"
Track the 2025's top emerging AI startups and their innovations, deliver a clean summary.

Output must be in Markdown format with:
- Main heading: Latest Generative AI (2025)
- Subheadings per key model or development
- Bullet points for features
- Source links if any
Keep it concise.


"""

# Run it
response_2 = agent.run(prompt_2)
# Out:
# > Entering new AgentExecutor chain...
# I need to search for the top emerging AI startups in 2025 and their innovations. I will use TavilySafeSearch to find this information.
# Action: TavilySafeSearch
# Action Input: Top emerging AI startups 2025
# Observation: [{'url': 'https://www.startupblink.com/blog/top-ai-startups/', 'content': 'the future of physical operations through intelligent automation. [...] # Top AI Startups in 2025\n\nStartupBlink Blog\n\nImage 1: logo\n\nImage 2: startupblink_logo_white 1\n\n   Global Map\n   Ecosystem Rankings\n   About\n   Services\n       Ecosystem Development\n       Corporate Startup Programs\n       Data Solutions\n       Portals\n\n   Reports\n   Blog\n   Contact\n   Log In\n\n   Global Map\n   Ecosystem Rankings\n   About\n   Services\n       Ecosystem Development\n       Corporate Startup Programs\n       Data Solutions\n       Portals\n\n   Reports\n   Blog\n   Contact\n   Log In\n\n1.   Home\n2.   /\n3.   Innovation Industries\n4.   /\n5.   Artificial Intelligence\n6.   /\n7.   Top AI Startups in…\n\nImage 3: top ai startups\n\n1.   Artificial Intelligence\n2.   Innovation Industries\n\n# Top AI Startups in 2025\n\nImage 5: StartupBlink [...] subsidiaries, the platform remains a cornerstone of China’s industry-focused cloud strategy.'}, {'url': 'https://www.linkedin.com/pulse/linkedin-top-startups-2025-50-us-companies-rise-linkedin-news-hox6f', 'content': "AI chatbot Perplexity snagged the No. 1 spot for the second year in a row. But I’ve loved seeing fresh faces on the list, too — newbies like GOODLES mac-and-cheese, AI-powered teacher’s assistant MagicSchool AI and David protein bars are all innovating and disrupting their industries. I hope you’ll enjoy exploring these companies as much as we have.\n\nThis ranking is built entirely on LinkedIn data looking at different elements of growth and demand, like employee growth, jobseeker interest and how well these startups pull talent from our LinkedIn Top Companies list. To be eligible, companies must be U.S.-based, fully independent, privately held and 5 years old or younger. [...] Full-time headcount: 60 | Headquarters: San Francisco | Year founded: 2025 | Most common skills: Python, Applied Machine Learning, Computer Vision | Most common job titles: Technical Staff Member, Operations Manager | Largest job functions: Engineering, Operations, Business Development | What they do: Co-founded by former OpenAI CTO Mira Murati, Thinking Machines Lab is a newly-launched AI startup focused on both advancing the technology and making it more broadly accessible. Its first product, Tinker —an API for fine-tuning AI models —launched in early October.\n\nSee more about Thinking Machines Lab | See people you may know\n\n### 10. Inworld AI\n\nImage 12: Profile image\n\n### Inworld AI Software Development Mountain View, CaliforniaFollow [...] ## Similar topics\n\n   Top Startups Driving AI Innovation 8 Posts Image 112Image 113Image 114 2,468 \n   Top AI Startups in Venture Capital 5 Posts Image 115Image 116Image 117 827 \n   AI Companies for Investors to Watch 6 Posts Image 118Image 119Image 120 614 \n   Types of Startups That Attract Investment 5 Posts Image 121Image 122Image 123 530 \n   Top Innovative Startups to Follow 8 Posts Image 124Image 125Image 126 1,117 \n   Communicating AI Startup Value on LinkedIn 6 Posts Image 127Image 128Image 129 828 \n   How to Assess AI Startups for True Value 10 Posts Image 130Image 131Image 132 5,838 \n   Future of AI with OpenAI's High-Valued Fundraising 10 Posts Image 133Image 134Image 135 1,027 \n\n Show more  Show less \n\n## Explore content categories"}, {'url': 'https://techcrunch.com/2026/01/19/here-are-the-49-us-ai-startups-that-have-raised-100m-or-more-in-2025/', 'content': 'Cambridge, Massachusetts’s based OpenEvidence, which builds an AI chatbot for the medical field, raised its second funding round of 2025. The $200 million Series C round was announced on October 20 and valued the company at $6 billion.\n\n Lila Sciences, which is looking to build a science superintelligence platform, announced its second funding round of 2025 on October 14. The $350 million Series A round was co-led by Braidwell and Collective Global.\n\n DeepSeek competitor  ...
# Thought:Based on the search results, there are several AI startups that have emerged as leaders in 2025. These include Perplexity, MagicSchool AI, Thinking Machines Lab, Inworld AI, OpenEvidence, Lila Sciences, Reflection AI, Celestial AI, Anysphere (Cursor), xAI, Thinking Machine Labs, World Labs, Writer, and others. I will now compile this information into a markdown format as requested.
# Final Answer:
# # Latest Generative AI (2025)
#
# ## Perplexity
# - AI chatbot
# - Ranked No. 1 for the second year in a row
# - [Source](https://www.linkedin.com/pulse/linkedin-top-startups-2025-50-us-companies-rise-linkedin-news-hox6f)
#
# ## MagicSchool AI
# - AI-powered teacher’s assistant
# - [Source](https://www.linkedin.com/pulse/linkedin-top-startups-2025-50-us-companies-rise-linkedin-news-hox6f)
#
# ## Thinking Machines Lab
# - Co-founded by former OpenAI CTO Mira Murati
# - Focused on advancing AI technology and making it more broadly accessible
# - [Source](https://www.linkedin.com/pulse/linkedin-top-startups-2025-50-us-companies-rise-linkedin-news-hox6f)
#
# ## Inworld AI
# - Software Development
# - [Source](https://www.linkedin.com/pulse/linkedin-top-startups-2025-50-us-companies-rise-linkedin-news-hox6f)
#
# ## OpenEvidence
# - Builds an AI chatbot for the medical field
# - [Source](https://techcrunch.com/2026/01/19/here-are-the-49-us-ai-startups-that-have-raised-100m-or-more-in-2025/)
#
# ## Lila Sciences
# - Looking to build a science superintelligence platform
# - [Source](https://techcrunch.com/2026/01/19/here-are-the-49-us-ai-startups-that-have-raised-100m-or-more-in-2025/)
#
# ## Reflection AI
# - DeepSeek competitor
# - [Source](https://techcrunch.com/2026/01/19/here-are-the-49-us-ai-startups-that-have-raised-100m-or-more-in-2025/)
#
# ## Celestial AI
# - AI infrastructure company
# - [Source](https://techcrunch.com/2026/01/19/here-are-the-49-us-ai-startups-that-have-raised-100m-or-more-in-2025/)
#
# ## Anysphere (Cursor)
# - Helps engineers write and edit code
# - [Source](https://www.forbes.com/lists/ai50/)
#
# ## xAI
# - Funded by Elon Musk
# - [Source](https://www.forbes.com/lists/ai50/)
#
# ## Thinking Machine Labs
# - Developing broadly capable AI systems
# - [Source](https://www.forbes.com/lists/ai50/)
#
# ## World Labs
# - Developing models that can understand physical spaces
# - [Source](https://www.forbes.com/lists/ai50/)
#
# ## Writer
# - Training its own models to handle mundane business tasks like writing marketing blogs and searching through troves of documents
# - [Source](https://www.forbes.com/lists/ai50/)
#
# > Finished chain.

# %%
display(Markdown(response_2))
# Out:
# # Latest Generative AI (2025)
#
# ## Perplexity
# - AI chatbot
# - Ranked No. 1 for the second year in a row
# - [Source](https://www.linkedin.com/pulse/linkedin-top-startups-2025-50-us-companies-rise-linkedin-news-hox6f)
#
# ## MagicSchool AI
# - AI-powered teacher’s assistant
# - [Source](https://www.linkedin.com/pulse/linkedin-top-startups-2025-50-us-companies-rise-linkedin-news-hox6f)
#
# ## Thinking Machines Lab
# - Co-founded by former OpenAI CTO Mira Murati
# - Focused on advancing AI technology and making it more broadly accessible
# - [Source](https://www.linkedin.com/pulse/linkedin-top-startups-2025-50-us-companies-rise-linkedin-news-hox6f)
#
# ## Inworld AI
# - Software Development
# - [Source](https://www.linkedin.com/pulse/linkedin-top-startups-2025-50-us-companies-rise-linkedin-news-hox6f)
#
# ## OpenEvidence
# - Builds an AI chatbot for the medical field
# - [Source](https://techcrunch.com/2026/01/19/here-are-the-49-us-ai-startups-that-have-raised-100m-or-more-in-2025/)
#
# ## Lila Sciences
# - Looking to build a science superintelligence platform
# - [Source](https://techcrunch.com/2026/01/19/here-are-the-49-us-ai-startups-that-have-raised-100m-or-more-in-2025/)
#
# ## Reflection AI
# - DeepSeek competitor
# - [Source](https://techcrunch.com/2026/01/19/here-are-the-49-us-ai-startups-that-have-raised-100m-or-more-in-2025/)
#
# ## Celestial AI
# - AI infrastructure company
# - [Source](https://techcrunch.com/2026/01/19/here-are-the-49-us-ai-startups-that-have-raised-100m-or-more-in-2025/)
#
# ## Anysphere (Cursor)
# - Helps engineers write and edit code
# - [Source](https://www.forbes.com/lists/ai50/)
#
# ## xAI
# - Funded by Elon Musk
# - [Source](https://www.forbes.com/lists/ai50/)
#
# ## Thinking Machine Labs
# - Developing broadly capable AI systems
# - [Source](https://www.forbes.com/lists/ai50/)
#
# ## World Labs
# - Developing models that can understand physical spaces
# - [Source](https://www.forbes.com/lists/ai50/)
#
# ## Writer
# - Training its own models to handle mundane business tasks like writing marketing blogs and searching through troves of documents
# - [Source](https://www.forbes.com/lists/ai50/)

# %% [markdown]
# ### Exercice 3: Compare Two Tech Products
# - **Prompt idea:** Compare the key features, pricing, and reviews of OpenAI’s ChatGPT Team and Anthropic’s Claude Pro.
# - Ensure the agent outputs a structured response in Markdown.

# %%
# Your prompt here
prompt_3 = """"
Compare the key features, pricing and reviews of OpenAi's ChatGPT Team and Anthropic's Claude Pro, deliver a clean summary.

Output must be in Markdown format with:
- Main heading: Latest Generative AI (2025)
- Subheadings per key model or development
- Bullet points for features
- Source links if any
Keep it concise.


"""

# Run it
response_3 = agent.run(prompt_3)
# Out:
# > Entering new AgentExecutor chain...
# I need to find information about the key features, pricing, and reviews of OpenAI's ChatGPT Team and Anthropic's Claude Pro. I will start by searching for information about OpenAI's ChatGPT Team.
# Action: TavilySafeSearch
# Action Input: "OpenAI ChatGPT Team key features, pricing and reviews"
# Observation: [{'url': 'https://openai.com/index/introducing-chatgpt-team/', 'content': 'Image 2: ChatGPT Team\n\nChatGPT Team includes:\n\n   Access to GPT‑4 with 32K context window\n   Tools like DALL·E 3, GPT‑4 with Vision, Browsing, Advanced Data Analysis—with higher message caps\n   No training on your business data or conversations\n   Secure workspace for your team\n   Create and share custom GPTs with your workspace\n   Admin console for workspace and team management\n   Early access to new features and improvements\n\n   Start now(opens in a new window)\n\n## Customize ChatGPT for any type of work [...] Dr. John Brownstein, Chief Innovation Officer at Boston Children’s Hospital says, “With ChatGPT Team, we’ve been able to pilot innovative GPTs that enhance our team’s productivity and collaboration. As we integrate GPTs safely and responsibly across internal operations, we know the transformative impact this will have in strengthening the systems that enable our doctors, researchers, students, and administrative staff to provide exceptional care to every patient that walks through our doors.”\n\nChatGPT Team costs $25/month per user when billed annually, or $30/month per user when billed monthly. You can explore the details or get started now by upgrading in your ChatGPT settings.\n\n   Explore ChatGPT Team\n   Try for free(opens in a new window)\n\n   ChatGPT\n   2024\n\n## References [...] Image 5: New board of directors\n\nOpenAI announces new members to board of directors Company Mar 8, 2024\n\nOur Research\n   Research Index\n   Research Overview\n   Research Residency\n   OpenAI for Science\n   Economic Research\n\nLatest Advancements\n   GPT-5.3 Instant\n   GPT-5.3-Codex\n   GPT-5\n   Codex\n\nSafety\n   Safety Approach\n   Security & Privacy\n   Trust & Transparency\n\nChatGPT\n   Explore ChatGPT(opens in a new window)\n   Business\n   Enterprise\n   Education\n   Pricing(opens in a new window)\n   Download(opens in a new window)\n\nSora\n   Sora Overview\n   Features\n   Pricing\n   Sora log in(opens in a new window)\n\nAPI Platform\n   Platform Overview\n   Pricing\n   API log in(opens in a new window)\n   Documentation(opens in a new window)\n   Developer Forum(opens in a new window)'}, {'url': 'https://intuitionlabs.ai/articles/chatgpt-plans-comparison', 'content': 'In January 2024, OpenAI filled the “middle” market with ChatGPT Teams (later renamed Business), a self-serve plan for small and mid-size teams (( "Highlights: Product")) (( "Highlights: How does the pricing work,for ChatGPT Business")). Teams offered collaboration (shared workspace, custom GPTs, admin tools) along with advanced models (GPT-4 with 32K context, premium DALL·E-3 images, browsing, data analysis) (( "Highlights: ChatGPT Team includes:")) (( "Highlights: ,to new features and improvements")). Business was priced per user ($25–$30), targeting fast-moving startups and departments. [...] # ChatGPT Business (Teams)\n\n### Overview and Features\n\nThe ChatGPT Business edition (formerly called _ChatGPT Team_) is aimed at groups, startups, and small-to-medium enterprises. It was introduced in January 2024 (( "Highlights: Product")) and rebranded to “Business” in mid-2025 (( "Highlights: Note: As of August 29th,,article: ChatGPT Business Rename FAQ")). Pricing is $25 per user/month (annual) or $30 on a monthly plan (( "Highlights: How does the pricing work,for ChatGPT Business")), with a minimum of 2 users. This plan builds on Plus (and Pro features) but adds collaboration, security, and management capabilities: [...] # ChatGPT Free Edition\n\n### Overview and Features\n\nThe Free edition (often just called “ChatGPT”) is the entry-level offering and remains available at no cost (( "Highlights: The new subscription plan, ChatGPT,will receive a number of benefits")). It gives users (one account = one seat) access to OpenAI’s latest models (now GPT-5) and standard tools (text/chat, images via DALL·E, voice) but with usage limits and reduced perfor ...
# Thought:From the search results, I have gathered the key features, pricing, and some reviews of OpenAI's ChatGPT Team. Now, I will search for information about Anthropic's Claude Pro.
# Action: TavilySafeSearch
# Action Input: "Anthropic Claude Pro key features, pricing and reviews"
# Observation: [{'url': 'https://aionx.co/chatgpt-reviews/claude-pro-features-complete-list/', 'content': '## Complete Feature List: What’s Included in Claude Pro\n\nClaude Pro subscribers get access to a comprehensive suite of features that extend far beyond the free tier’s basic chat capabilities. According to IntuitionLabs’ 2026 pricing analysis, Pro represents the best value tier for professionals who use AI daily. Here’s the complete breakdown based on Anthropic’s official documentation and March 2026 updates.\n\n### Model Access and Intelligence\n\nPro subscribers get full access to Anthropic’s entire model lineup, while free tier users are limited to Sonnet 4.5: [...] ## Pricing and Billing Options\n\nClaude Pro offers flexible billing options in 2026:\n\n   Monthly billing: $20 per month, cancel anytime with no commitment\n   Annual billing: $204 per year ($17 per month average, 15% savings)\n\nAccording to Juma’s comprehensive pricing analysis, the annual plan provides the best value for users who know they’ll use Claude consistently throughout the year. However, there’s a tradeoff: monthly billing offers flexibility to cancel if your needs change, while annual billing locks in savings but requires upfront commitment.\n\nTrial Period: Anthropic does not offer a free trial for Claude Pro. You’re billed immediately upon subscribing, but can cancel anytime with no penalties on the monthly plan.\n\n## Who Should Upgrade to Claude Pro? [...] Key Takeaways: Claude Pro ($20/month) provides 5x more usage than free tier (approximately 45 messages per 5-hour window), access to Claude Opus 4.6 and all model tiers, Claude Code for terminal-based development, Cowork for autonomous multi-step tasks across applications, Projects with unlimited storage, extended thinking with adaptive mode, Google Workspace integration, and priority access during peak times. Annual billing reduces cost to $17/month (15% savings).\n\n## Complete Feature List: What’s Included in Claude Pro'}, {'url': 'https://intuitionlabs.ai/articles/claude-pricing-plans-api-costs', 'content': '## Pro Plan\n\nThe Claude Pro plan is a fixed-price subscription targeted at power users and professionals. It costs $17/month (annual) or $20 month-to-month (( "Highlights: $17")), aligning it with major competitors (e.g. ChatGPT Plus at $20) (( "Highlights: Frequently working with longer documents,important to keep in mind")). For that price, Pro offers approximately 5× the usage of the Free plan (( "Highlights: For around $20/month, Claude Pro,service is in high demand")). In practice, this means longer conversations and the ability to handle larger tasks without hitting the usage cap. Anthropic has noted that Pro users get “around five times more usage of everything included in the free tier” (( "Highlights: For around $20/month, Claude Pro,service is in high demand")). [...] Productivity Integrations – Connect Google Workspace (Gmail, Calendar, Docs) and other tools to automate writer tasks (( "Highlights: ,through connectors with remote MCP")) (( "Highlights: For around $20/month, Claude Pro,service is in high demand")).\n   Extended Context and Tools – The ability to use larger context windows and connect third-party tools (via Anthropic’s new “tools” API) increases Claude’s depth of reasoning and data access (( "Highlights: ,to use more Claude models")).\n   Support for Multiple Models – Pro subscribers can choose from all available Claude models, not just the default (( "Highlights: But that’s not all,access to more Claude models")). [...] Consumer AI Competition: By pricing Pro at $20 and offering a robust free tier, Anthropic challenges OpenAI and Google. If users find Claude Pro clearer of throttling or more capable in tasks, the competitive pricing may shift market share. For example, a Tom’s Guide reviewer concludes Claude Pro was “worth paying for” because of its performance (( "Highlights: AI I found the only,it’s not what you think")). Sustained consumer adoption ...
# Thought:From the search results, I have gathered the key features, pricing, and some reviews of Anthropic's Claude Pro. Now, I can compile the information into a markdown format as requested.
# Final Answer:
# # Latest Generative AI (2025)
#
# ## OpenAI's ChatGPT Team
# - Access to GPT‑4 with 32K context window
# - Tools like DALL·E 3, GPT‑4 with Vision, Browsing, Advanced Data Analysis
# - Secure workspace for your team
# - Create and share custom GPTs with your workspace
# - Admin console for workspace and team management
# - Early access to new features and improvements
# - Pricing: $25/month per user when billed annually, or $30/month per user when billed monthly
# - Reviews: Positive feedback on its ability to enhance productivity and collaboration. [Source](https://openai.com/index/introducing-chatgpt-team/)
#
# ## Anthropic's Claude Pro
# - Full access to Anthropic’s entire model lineup
# - Claude Code for terminal-based development
# - Cowork for autonomous multi-step tasks across applications
# - Projects with unlimited storage
# - Extended thinking with adaptive mode
# - Google Workspace integration
# - Priority access during peak times
# - Pricing: $20 per month, cancel anytime with no commitment or $204 per year ($17 per month average, 15% savings)
# - Reviews: Considered the best value tier for professionals who use AI daily. [Source](https://aionx.co/chatgpt-reviews/claude-pro-features-complete-list/)
#
# > Finished chain.

# %%
display(Markdown(response_3))
# Out:
# # Latest Generative AI (2025)
#
# ## OpenAI's ChatGPT Team
# - Access to GPT‑4 with 32K context window
# - Tools like DALL·E 3, GPT‑4 with Vision, Browsing, Advanced Data Analysis
# - Secure workspace for your team
# - Create and share custom GPTs with your workspace
# - Admin console for workspace and team management
# - Early access to new features and improvements
# - Pricing: $25/month per user when billed annually, or $30/month per user when billed monthly
# - Reviews: Positive feedback on its ability to enhance productivity and collaboration. [Source](https://openai.com/index/introducing-chatgpt-team/)
#
# ## Anthropic's Claude Pro
# - Full access to Anthropic’s entire model lineup
# - Claude Code for terminal-based development
# - Cowork for autonomous multi-step tasks across applications
# - Projects with unlimited storage
# - Extended thinking with adaptive mode
# - Google Workspace integration
# - Priority access during peak times
# - Pricing: $20 per month, cancel anytime with no commitment or $204 per year ($17 per month average, 15% savings)
# - Reviews: Considered the best value tier for professionals who use AI daily. [Source](https://aionx.co/chatgpt-reviews/claude-pro-features-complete-list/)

# %% [markdown]
# ## Bonus Task: Propose and Implement Your Own Use Case
#
# As a final challenge, think of a real-world scenario where an AI agent could provide value using web search or external tools.

# %%
# Your prompt here
prompt_bonus = """"
In terms of health, wellbeing, and social equity, what are the best and worst things between living in Madrid and Barcelona. Deliver a clean summary.

Output must be in Markdown format with:
- Main heading: City
- Subheadings per feature
- Source links if any
Keep it concise.


"""

# Run it
response_bonus = agent.run(prompt_bonus)

display(Markdown(response_bonus))
# Out:
# > Entering new AgentExecutor chain...
# I need to find information about the health, wellbeing, and social equity in both Madrid and Barcelona. I will use TavilySafeSearch to find this information.
# Action: TavilySafeSearch
# Action Input: Health, wellbeing, and social equity in Madrid
# Observation: [{'url': 'https://distefar.com/en/the-health-sector-essential-for-the-well-being-of-the-population-and-an-economic-engine-for-society/', 'content': 'Madrid 13 March 2024.-The healthcare sector is one of the key pillars of the Spanish economy, to which it contributes 10.4% of Gross Domestic Product, very close to that of tourism and, therefore, one of Spain’s main economic and social drivers. The private initiative in the health sector is an unquestionable key element, as it has a direct impact on the provision of goods and services in different areas of society and in the productive sectors of the country’s economy: not only does it drive, promote and cover needs in the health sector, but it also plays a central role in the generation of economic value (between 54% and 58% of total health expenditure requires the private sector to provide services), the creation of qualified employment (with 7.5% of employees in Spain), the promotion [...] On the other hand, it is noteworthy that the pharmaceutical industry increased its sales abroad by 55%, reaching 27,442 million euros, which represents 7.1% of total exports in Spain.\n\n##### Employment, business and social equity\n\nAs the report shows, the private health sector employs more than one million people in Spain (direct and indirect impact). It is estimated that the total number of workers in the health insurance sector amounts to 6,892 people, workers in pharmacies to 70,122, the social and healthcare sector to more than 160,000, the technology sector to around 130,500 jobs and the pharmaceutical industry to 259,000 jobs.'}, {'url': 'https://health.ec.europa.eu/system/files/2016-11/ev_20131030_co11_en_0.pdf', 'content': 'of participants z Results for each working team and SPA { Methodological Guide version 1 { Innovative experience { Transferable process { Systematic process of review, useful as a cycle of improvement and assessment Health Equity Training Process in Spain: Integration of a focus on Social Determinants of Health and Equity into health strategies, programmes and activities (SPAs) at national and regional level Spanish Training Process II Ministry of Health, Social Services and Equality. Methodological Guide to integrate Equity into Health Strategies, Programmes and Activities. Version 1. Madrid 2012. Available at:  Spanish Training process: Overarching results 11 WHO Discussion Paper series on Social Determinants of Health: Integration of SDH and Equity into health SPAs: Health equity [...] health equity with an explicit but not exclusive focus on the Roma population WHO Multicountry training process: Overview 13 Process to integrate Equity into Health SPAs 13 Q U I T E Y Q U I T E Y Checklist Review Redesign WHO Multicountry training process: Methodology Preliminary review of the SPA with and equity focus E-Q-U-I-T-y Review cycle Equit-Y Final stage: implementation of the redesign recommendations identified in the review cycle Ministry of Health, Social Services and Equality. Methodological Guide to integrate Equity into Health Strategies, Programmes and Activities. Version 1. Madrid 2012. Available at:  Q U I T E Y 1. EXAMINE the SPA EXAMINE the SPA 2. QUESTIONING who accesses and benefits from the SPA 5. THINKING of the redesign plan 3. UNDERSTANDING the barriers and [...] 1 Progress on Health Equity work in Spain Meeting of the EU Expert Group on SDH and HI 29-30 October 2013, Luxembourg Begoña Merino and Pilar Campos Health Promotion Area. DG Public Health, Quality and Innovation. Ministry of Health Social Services and Equality. Spain Index 1. Spanish framework: National Strategy on Health Equity 2. Overview of the Health Equity review training process 3. National Strategy on Health Promotion and Disease Prevention 4. Health Equity and the Roma community 2 Index 1. Spanish framework: National Strategy on Health Equity 2.\nOverview of the Health Equity review training process 3.\nNational Strategy on Health Promotion and Disease Prevention 4.'}, ...
# Thought:The search results provide a lot of information about the health, wellbeing, and social equity in Madrid. The healthcare sector is a key pillar of the Spanish economy, contributing 10.4% of the Gross Domestic Product. The private sector plays a significant role in the provision of goods and services in different areas of society, including health. The private health sector employs more than one million people in Spain. There are efforts to integrate a focus on Social Determinants of Health and Equity into health strategies, programmes, and activities at the national and regional level. There are also policies and interventions to reduce social inequalities in health. However, there are still health inequalities, with differences in life expectancy between the richest and poorest Autonomous Communities. Private insurance is concentrated in Madrid, among other places. There are also social inequalities in health, lifestyles, and the utilisation of healthcare services. The immigrant population and individuals with limited personal resources face challenges in accessing healthcare services. The Gini Coefficient, which measures income inequality, is 33. Homeless individuals encounter difficulties in accessing public healthcare services, which constitutes an important inequity. Now I will search for similar information about Barcelona.
# Action: TavilySafeSearch
# Action Input: Health, wellbeing, and social equity in Barcelona
# Observation: [{'url': 'https://theprogressplaybook.com/2026/02/27/catalonias-housing-revolution-where-affordability-meets-sustainability/', 'content': 'Indicators of the system’s emissions savings are also beginning to materialise: for instance, according to data from the Catalan Institute of Energy, the retrofits completed between 2020 and 2024 are saving an estimated 18,000 tonnes of CO2 annually. And energy poverty is decreasing in the participating neighbourhoods: households once spending 20% of income on utilities now spend less than 10%. One Barcelona city report found that for every euro spent on retrofits saved €2.30 in health costs and energy subsidies, demonstrating the multiplier effect that climate action often has on social equity. “If you find the right solutions, the social and the environmental impacts are often mutually reinforcing,” says Ángel Perez, director of energy management company SALAS Green Power. Compared to [...] “Utimately, we believe housing should be the fifth pillar of the welfare state alongside healthcare, education, pensions and social services,” says Hàbitat3’s president Carme Trilla, who is also president of Cohabitac. It is a sentiment shared by Barcelona Housing Commissioner Riera. Spain currently spends 7.5% of its GDP on healthcare, 4.5% of education and a mere 0.2% on housing. “But the cost of housing for the population ends up undermining the other pillars of the welfare state,” argues Trilla. “Private companies have an important role to play in the housing system, but it should be as service providers rather than managers and owners, as they do in areas like healthcare.”'}, {'url': 'https://www.sciencedirect.com/science/article/pii/S0264275125001623', 'content': "Forty years after its inception, the Barcelona Health Report stands as a milestone in a long tradition of accountability to society regarding the health situation and its determinants in the city. This long-standing initiative reflects a continued political commitment to creating spaces for debate, transparency, and evidence-based policy-making. Also, it shows Barcelona's political commitment to promoting health equity. The lessons learned from this experience can provide valuable insights for other cities, particularly in Southern Europe, looking to enhance their health governance and policy frameworks through evidence-based approaches.\n\n## Keywords\n\nUrban health\n\nHealth reporting\n\nHealth policies\n\nInequalities in health\n\n## Data availability\n\nData will be made available on request. [...] The first section outlines the city's main characteristics, including its challenges and the description of public health in the city. Then we follow with an overview of the 40 years of health reports in the city, explaining the evolution through the years. Finally, we present five examples of how evidence on health and health impact of policies has been used to inform and drive public policies of housing, climate change, transport and road safety, socioeconomic inequalities, and COVID-19 inequalities. [...] Five examples of how evidence on health and health impact of policies are presented to drive public policies.\n •\n\n  The lessons learned from this experience can provide valuable insights for other cities.\n\n## Abstract\n\nThis article profiles the city of Barcelona, focusing on public health and its 40-year history of Health Reporting, and how these reports help to implement evidence-based policies."}, {'url': 'https://climate-adapt.eea.europa.eu/en/metadata/case-studies/barcelona-trees-tempering-the-mediterranean-city-climate', 'content': 'The City Administration started testing interventions to increase urban greening and improve liveability of streets and spaces with the Superblock programme. The Barcelona Urban Mobility Plan (UMP) from 2013-2018 set the objectives to foster positive social cohesion and public health through a transformation of streets and squares in the neighbourhood of Eixample. This objective w ...
# Thought:The search results provide a lot of information about the health, wellbeing, and social equity in Barcelona. There are efforts to make the city more egalitarian, with emphasis on women’s health, culture, sports, and employment. The city has a tradition of urban planning initiatives that promote basic services and enhance citizens’ well-being. The Barcelona Urban Mobility Plan aims to foster positive social cohesion and public health through a transformation of streets and squares. The Superblock programme aims to reduce greenhouse gas emissions and adapt the neighbourhoods to climate change, while improving environmental conditions to increase well-being in Barcelona. The city also has services to assist victims of gender violence and human trafficking. The primary healthcare centre (CAP) is the first point of call for free medical assistance. More serious health issues are dealt with in hospitals. To register with the Catalan healthcare service (CatSalut), you need to be registered with the municipal residents' register (padrón). If you are not working or paying into the Social Security system, you will have to take out private medical insurance that covers you while you are living in Spain. Now I can summarize the information and present it in the required format.
# Final Answer:
# # Madrid
# ## Health and Wellbeing
# Madrid's healthcare sector is a key pillar of the Spanish economy, contributing 10.4% of the Gross Domestic Product. The private sector plays a significant role in the provision of goods and services in different areas of society, including health. The private health sector employs more than one million people in Spain. There are efforts to integrate a focus on Social Determinants of Health and Equity into health strategies, programmes, and activities at the national and regional level. There are also policies and interventions to reduce social inequalities in health. However, there are still health inequalities, with differences in life expectancy between the richest and poorest Autonomous Communities. Private insurance is concentrated in Madrid, among other places. There are also social inequalities in health, lifestyles, and the utilisation of healthcare services. The immigrant population and individuals with limited personal resources face challenges in accessing healthcare services. [Source](https://distefar.com/en/the-health-sector-essential-for-the-well-being-of-the-population-and-an-economic-engine-for-society/)
# ## Social Equity
# The Gini Coefficient, which measures income inequality, is 33. Homeless individuals encounter difficulties in accessing public healthcare services, which constitutes an important inequity. [Source](https://healthsystemsfacts.org/spain/spain-social-determinants-health-equity/)
#
# # Barcelona
# ## Health and Wellbeing
# Barcelona has moved forward towards a more egalitarian city that has emphasized women’s health, culture, sports, and employment. The Barcelona Urban Mobility Plan aims to foster positive social cohesion and public health through a transformation of streets and squares. The Superblock programme aims to reduce greenhouse gas emissions and adapt the neighbourhoods to climate change, while improving environmental conditions to increase well-being in Barcelona. The city also has services to assist victims of gender violence and human trafficking. The primary healthcare centre (CAP) is the first point of call for free medical assistance. More serious health issues are dealt with in hospitals. [Source](https://www.citieschange.org/cities/barcelona/)
# ## Social Equity
# To register with the Catalan healthcare service (CatSalut), you need to be registered with the municipal residents' register (padrón). If you are not working or paying into the Social Security system, you will have to take out private medical insurance that covers you while you are living in Spain. [Source](https://www.barcelona.cat/internationalwelcome/en/need/healthcare/public-healthcare-system)
#
# > Finished chain.
# # Madrid
# ## Health and Wellbeing
# Madrid's healthcare sector is a key pillar of the Spanish economy, contributing 10.4% of the Gross Domestic Product. The private sector plays a significant role in the provision of goods and services in different areas of society, including health. The private health sector employs more than one million people in Spain. There are efforts to integrate a focus on Social Determinants of Health and Equity into health strategies, programmes, and activities at the national and regional level. There are also policies and interventions to reduce social inequalities in health. However, there are still health inequalities, with differences in life expectancy between the richest and poorest Autonomous Communities. Private insurance is concentrated in Madrid, among other places. There are also social inequalities in health, lifestyles, and the utilisation of healthcare services. The immigrant population and individuals with limited personal resources face challenges in accessing healthcare services. [Source](https://distefar.com/en/the-health-sector-essential-for-the-well-being-of-the-population-and-an-economic-engine-for-society/)
# ## Social Equity
# The Gini Coefficient, which measures income inequality, is 33. Homeless individuals encounter difficulties in accessing public healthcare services, which constitutes an important inequity. [Source](https://healthsystemsfacts.org/spain/spain-social-determinants-health-equity/)
#
# # Barcelona
# ## Health and Wellbeing
# Barcelona has moved forward towards a more egalitarian city that has emphasized women’s health, culture, sports, and employment. The Barcelona Urban Mobility Plan aims to foster positive social cohesion and public health through a transformation of streets and squares. The Superblock programme aims to reduce greenhouse gas emissions and adapt the neighbourhoods to climate change, while improving environmental conditions to increase well-being in Barcelona. The city also has services to assist victims of gender violence and human trafficking. The primary healthcare centre (CAP) is the first point of call for free medical assistance. More serious health issues are dealt with in hospitals. [Source](https://www.citieschange.org/cities/barcelona/)
# ## Social Equity
# To register with the Catalan healthcare service (CatSalut), you need to be registered with the municipal residents' register (padrón). If you are not working or paying into the Social Security system, you will have to take out private medical insurance that covers you while you are living in Spain. [Source](https://www.barcelona.cat/internationalwelcome/en/need/healthcare/public-healthcare-system)
